# %%
import pymysql
import pandas as pd

# Connection parameters
endpoint = "127.0.0.1"      # Usually localhost
username = "root"           # DB username
password = "Sakshi@123"     # DB password
database = "mini_project"   # Database name
port = 3306

# Create connection
try:
    connection = pymysql.connect(
        host=endpoint,
        user=username,
        password=password,
        database=database,
        port=port,
        charset='utf8mb4'
    )
    print("✅ Connection successful!")
except Exception as e:
    print("❌ Connection failed!")
    print(e)
# Out:
# ✅ Connection successful!

# %%
# Show all tables in the database
query = "SHOW TABLES;"
tables = pd.read_sql(query, connection)
print("Tables in database:", tables)
# Out:
# Tables in database:   Tables_in_mini_project
# 0              customers
# 1              locations
# 2            order_items
# 3                 orders
# 4               products
# 5         raw_store_data
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2799586986.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, connection)

# %%
query = "SELECT * FROM order_items LIMIT 5;"
df = pd.read_sql(query, connection)
print(df)
# Out:
#    item_id  row_id        order_id       product_id  \
# 0        1       1  CA-2016-152156  FUR-BO-10001798
# 1        2       2  CA-2016-152156  FUR-CH-10000454
# 2        3       3  CA-2016-138688  OFF-LA-10000240
# 3        4       4  US-2015-108966  FUR-TA-10000577
# 4        5       5  US-2015-108966  OFF-ST-10000760
#
#                                         product_name  quantity   sales  \
# 0                  Bush Somerset Collection Bookcase         2  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3  731.94
# 2  Self-Adhesive Address Labels for Typewriters b...         2   14.62
# 3      Bretford CR4500 Series Slim Rectangular Table         5  957.58
# 4                     Eldon Fold 'N Roll Cart System         2   22.37
#
#    discount  profit
# 0      0.00   41.91
# 1      0.00  219.58
# 2      0.00    6.87
# 3      0.45 -383.03
# 4      0.20    2.52
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\739884743.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
import pymysql

endpoint = "127.0.0.1"
username = "root"
password = "Sakshi@123"
database = "mini_project"
port = 3306

connection = pymysql.connect(
    host=endpoint,
    user=username,
    password=password,
    database=database,
    port=port,
    charset='utf8mb4'
)

# %%
import pandas as pd

query = """
SELECT 
    l.region,
    c.segment,
    SUM(oi.sales) AS total_sales,
    SUM(oi.profit) AS total_profit,
    COUNT(DISTINCT o.order_id) AS order_count,
    COUNT(DISTINCT c.customer_id) AS customer_count,
    AVG(oi.sales) AS avg_order_value
FROM order_items oi
JOIN orders o ON oi.order_id = o.order_id
JOIN customers c ON o.customer_id = c.customer_id
JOIN locations l ON o.location_id = l.location_id
GROUP BY l.region, c.segment
ORDER BY l.region, c.segment
"""

df = pd.read_sql(query, connection)
print(df.head())  
print(df.shape)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\3735073472.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#     region      segment  total_sales  total_profit  order_count  \
# 0  Central     Consumer    249892.57       9042.32          596
# 1  Central    Corporate    157157.68      18661.50          344
# 2  Central  Home Office     90750.63      12425.13          221
# 3     East     Consumer    347820.22      40418.06          699
# 4     East    Corporate    197498.23      23642.74          427
#
#    customer_count  avg_order_value
# 0             325       211.594047
# 1             180       241.039387
# 2             121       212.530749
# 3             341       244.771443
# 4             206       231.805434
# (12, 7)

# %%
# Check all databases
query = "SHOW DATABASES;"
dbs = pd.read_sql(query, connection)
print(dbs)
# Out:
#              Database
# 0             campusx
# 1  information_schema
# 2        mini_project
# 3               mysql
# 4  performance_schema
# 5                 sys
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2804358204.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dbs = pd.read_sql(query, connection)

# %%
# Check tables in mini_project
query = "SHOW TABLES;"
tables = pd.read_sql(query, connection)
print(tables)
# Out:
#   Tables_in_mini_project
# 0              customers
# 1              locations
# 2            order_items
# 3                 orders
# 4               products
# 5         raw_store_data
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\338688030.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql(query, connection)

# %%
query = "SELECT * FROM orders LIMIT 5;"
df = pd.read_sql(query, connection)
print(df)
# Out:
#          order_id customer_id  location_id  order_date   ship_date  \
# 0  CA-2014-100006    DK-13375           24  2014-09-07  2014-09-13
# 1  CA-2014-100090    EB-13705           35  2014-07-08  2014-07-12
# 2  CA-2014-100293    NF-18475          133  2014-03-14  2014-03-18
# 3  CA-2014-100363    JM-15655          275  2014-04-08  2014-04-15
# 4  CA-2014-100391    BW-11065           46  2014-05-25  2014-05-29
#
#         ship_mode
# 0  Standard Class
# 1  Standard Class
# 2  Standard Class
# 3  Standard Class
# 4  Standard Class
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\80435313.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
import os
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', 'customer_segmentation.png', 'Mini Porject-ER and Visualizations.docx', 'Miniproject.ipynb', 'miniproject.sql', 'mini_project_store.csv', 'README.md', 'regional_performance.png', 'Region_Segment_Analysis.ipynb', 'sales_by_category.png', 'time_series_analysis.png', 'untitled.txt']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DELL\MySQL-Python-Data-Analytics-Mini-Project

# %%
import pandas as pd

orders = pd.read_sql("SELECT * FROM orders", connection)
customers = pd.read_sql("SELECT * FROM customers", connection)
order_items = pd.read_sql("SELECT * FROM order_items", connection)
locations = pd.read_sql("SELECT * FROM locations", connection)
products = pd.read_sql("SELECT * FROM products", connection)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2606822994.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orders = pd.read_sql("SELECT * FROM orders", connection)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2606822994.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customers = pd.read_sql("SELECT * FROM customers", connection)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2606822994.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_items = pd.read_sql("SELECT * FROM order_items", connection)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2606822994.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   locations = pd.read_sql("SELECT * FROM locations", connection)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15092\2606822994.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   products = pd.read_sql("SELECT * FROM products", connection)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DELL\MySQL-Python-Data-Analytics-Mini-Project

# %% [markdown]
# import os
# print(os.listdir())

# %% [markdown]
# """
#
# Datasets Used
#
#  1. Orders
# - Order ID
# - Order Date
# - Customer ID
# - Region
#
#  2. Customers
# - Customer ID
# - Customer Name
# - Segment
#
#  3. Order Items
# - Order ID
# - Product ID
# - Sales
# - Quantity
# - Profit
#
# """

# %%
"""
Business Questions:

1. Which region generates the highest sales?
2. Which customer segment contributes most revenue?
3. Which region-segment combination performs best?
4. What are the profit trends across segments?
5. Are there low performing regions needing attention?
"""
# Out:
# '\nBusiness Questions:\n\n1. Which region generates the highest sales?\n2. Which customer segment contributes most revenue?\n3. Which region-segment combination performs best?\n4. What are the profit trends across segments?\n5. Are there low performing regions needing attention?\n'
